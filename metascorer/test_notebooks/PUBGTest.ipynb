# %%
import requests
import time

# %%
headers = {"Accept": "application/vnd.api+json",
         "Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiIzMTY4MmVhMC03OTE0LTAxMzgtYWYyNi0wMDNiMDE4NjQ5MzkiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNTg5NTcyNjMzLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImphY2tpZS11cGxldmVsIn0.6LixccqXITLvrQFT6S-Np7ofo82ZUbSaqul8f8UkERk"}

# %%
res = requests.get("https://api.pubg.com/shards/steam/players?filter[playerNames]=WackyJacky101", headers = headers)

# %%
res
# Out:
# <Response [200]>

# %%
match_list = res.json()['data'][0]['relationships']['matches']['data']
match_list
# Out:
# [{'type': 'match', 'id': '70e02108-8907-47da-b0c9-d997af6770ad'},
#  {'type': 'match', 'id': '565427da-982a-4724-a095-66fb2d17c254'},
#  {'type': 'match', 'id': '125dba03-31cb-40f6-bbe1-403457a5e5b6'},
#  {'type': 'match', 'id': 'fb9a8c99-3b42-441b-9745-4e707b8a3ee0'},
#  {'type': 'match', 'id': 'd77307f3-f46c-4a54-bfbd-43467e62f1bb'},
#  {'type': 'match', 'id': 'd8d0fe27-6da4-4021-aaaf-0aa6544b2b88'},
#  {'type': 'match', 'id': '825e3bff-39dc-46ec-a6e9-acd555be221a'},
#  {'type': 'match', 'id': '49112748-49be-47c2-b0b7-59b5dfb61ca0'},
#  {'type': 'match', 'id': '794f4ab8-05a1-4073-976b-fa2744db44e9'},
#  {'type': 'match', 'id': '02e98cc3-ea2e-45e4-81bb-914a7424cef8'},
#  {'type': 'match', 'id': '28b44adc-16e0-4d7c-97bb-418df12aff8d'},
#  {'type': 'match', 'id': '338b9344-6f4c-4e8f-95b5-be62df177ca2'},
#  {'type': 'match', 'id': 'deb059c2-9886-4449-a827-50e20a2bba19'},
#  {'type': 'match', 'id': '04dec7ca-a1f6-4e03-a000-d97beaf939bf'},
# ...

# %%
first_match = match_list[1]
first_match
# Out:
# {'type': 'match', 'id': '565427da-982a-4724-a095-66fb2d17c254'}

# %%
requests.get("https://api.pubg.com/shards/steam/matches/565427da-982a-4724-a095-66fb2d17c254", headers=headers).json()
# Out:
# {'data': {'type': 'match',
#   'id': '565427da-982a-4724-a095-66fb2d17c254',
#   'attributes': {'gameMode': 'solo-fpp',
#    'titleId': 'bluehole-pubg',
#    'tags': None,
#    'seasonState': 'progress',
#    'createdAt': '2020-05-12T19:09:19Z',
#    'duration': 1819,
#    'stats': None,
#    'shardId': 'steam',
#    'mapName': 'Baltic_Main',
#    'isCustomMatch': False,
#    'matchType': 'official'},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': 'ef66a4e0-3417-46ba-bce8-23ed6b172a65'},
#      {'type': 'roster', 'id': 'ed521e1f-77bd-4c35-985f-28e49e5ed3b9'},
#      {'type': 'roster', 'id': 'b625d920-09ab-411a-9be8-e8e5b9ec4039'},
#      {'type': 'roster', 'id': '0eb8ba37-f4f0-47f9-a50a-9df3f1070a55'},
#      {'type': 'roster', 'id': 'bf1e9588-6203-46b3-8879-7bf5394780cb'},
#      {'type': 'roster', 'id': '84c93e3f-d0e9-468c-9b04-dadeb2131480'},
#      {'type': 'roster', 'id': '320feae9-0de8-4ce2-a27d-5cc8e0096dc7'},
# ...

# %%
requests.get("https://api.pubg.com/shards/steam/matches/565427da-982a-4724-a095-66fb2d17c254", headers=headers).json()['data']['attributes']
# Out:
# {'gameMode': 'solo-fpp',
#  'titleId': 'bluehole-pubg',
#  'tags': None,
#  'seasonState': 'progress',
#  'createdAt': '2020-05-12T19:09:19Z',
#  'duration': 1819,
#  'stats': None,
#  'shardId': 'steam',
#  'mapName': 'Baltic_Main',
#  'isCustomMatch': False,
#  'matchType': 'official'}

# %%
for match in match_list:
    id_ = match['id']
    match_details = requests.get("https://api.pubg.com/shards/steam/matches/" + str(id_), headers=headers).json()
    print(match_details['data']['attributes']['createdAt'])
# Out:
# 2020-05-12T19:20:48Z
# 2020-05-12T19:09:19Z
# 2020-05-12T18:52:12Z
# 2020-05-12T18:26:46Z
# 2020-05-12T18:09:26Z
# 2020-05-12T13:18:33Z
# 2020-05-12T13:08:21Z
# 2020-05-12T13:03:35Z
# 2020-05-12T12:51:44Z
# 2020-05-12T12:33:56Z
# 2020-05-12T12:30:38Z
# 2020-05-12T12:15:33Z
# 2020-05-12T12:08:49Z
# 2020-05-12T12:04:19Z
# 2020-05-09T19:40:51Z
# 2020-05-09T19:25:41Z
# 2020-05-09T19:17:24Z
# 2020-05-09T19:11:29Z
# 2020-05-09T18:54:23Z
# 2020-05-09T18:35:48Z
# 2020-05-09T18:26:42Z
# 2020-05-09T18:21:23Z
# 2020-05-09T18:13:04Z
# 2020-05-08T21:10:53Z
# 2020-05-08T20:49:55Z
# 2020-05-08T20:23:19Z
# 2020-05-08T19:56:35Z
# 2020-05-08T18:19:31Z
# 2020-05-08T18:15:07Z
# 2020-05-07T19:40:53Z
# 2020-05-07T19:12:47Z
# 2020-05-07T19:03:02Z
# 2020-05-07T18:58:13Z
# 2020-05-07T18:34:44Z
# 2020-05-07T18:12:42Z
# 2020-05-07T12:37:28Z
# 2020-05-07T12:27:52Z
# 2020-05-07T12:01:10Z
# 2020-05-07T11:53:12Z
# 2020-05-07T11:41:28Z
# 2020-05-07T11:38:30Z
# 2020-05-07T11:15:14Z
# 2020-05-07T11:01:23Z
# ...

# %%
date_list = []

for match in match_list:
    id_ = match['id']
    match_details = requests.get("https://api.pubg.com/shards/steam/matches/" + str(id_), headers=headers).json()
    date_list.append(match_details['data']['attributes']['createdAt'])

# %%
import pandas as pd
example_df = pd.DataFrame({"date": date_list})

# %%
example_df['real_date'] = pd.to_datetime(example_df['date'])
example_df
# Out:
#                     date                 real_date
# 0   2020-05-12T19:20:48Z 2020-05-12 19:20:48+00:00
# 1   2020-05-12T19:09:19Z 2020-05-12 19:09:19+00:00
# 2   2020-05-12T18:52:12Z 2020-05-12 18:52:12+00:00
# 3   2020-05-12T18:26:46Z 2020-05-12 18:26:46+00:00
# 4   2020-05-12T18:09:26Z 2020-05-12 18:09:26+00:00
# ..                   ...                       ...
# 71  2020-05-03T20:06:03Z 2020-05-03 20:06:03+00:00
# 72  2020-05-03T19:37:33Z 2020-05-03 19:37:33+00:00
# 73  2020-05-03T18:58:09Z 2020-05-03 18:58:09+00:00
# 74  2020-05-03T18:32:10Z 2020-05-03 18:32:10+00:00
# 75  2020-05-03T18:07:29Z 2020-05-03 18:07:29+00:00
#
# [76 rows x 2 columns]

# %%
hourly_df = example_df.resample('H', on = 'real_date').count()
hourly_df
# Out:
#                            date  real_date
# real_date
# 2020-05-03 18:00:00+00:00     3          3
# 2020-05-03 19:00:00+00:00     1          1
# 2020-05-03 20:00:00+00:00     2          2
# 2020-05-03 21:00:00+00:00     3          3
# 2020-05-03 22:00:00+00:00     0          0
# ...                         ...        ...
# 2020-05-12 15:00:00+00:00     0          0
# 2020-05-12 16:00:00+00:00     0          0
# 2020-05-12 17:00:00+00:00     0          0
# 2020-05-12 18:00:00+00:00     3          3
# 2020-05-12 19:00:00+00:00     2          2
#
# [218 rows x 2 columns]

# %%
isWorkingHours = []

# 0 is Monday, 6 is Sunday
for i in hourly_df.index:
    print(i.dayofweek, i.dayofweek in range(5), i.hour, (i.hour > 12 and i.hour < 14) or i.hour > 18 )
# Out:
# 6 False 18 False
# 6 False 19 True
# 6 False 20 True
# 6 False 21 True
# 6 False 22 True
# 6 False 23 True
# 0 True 0 False
# 0 True 1 False
# 0 True 2 False
# 0 True 3 False
# 0 True 4 False
# 0 True 5 False
# 0 True 6 False
# 0 True 7 False
# 0 True 8 False
# 0 True 9 False
# 0 True 10 False
# 0 True 11 False
# 0 True 12 False
# 0 True 13 True
# 0 True 14 False
# 0 True 15 False
# 0 True 16 False
# 0 True 17 False
# 0 True 18 False
# 0 True 19 True
# 0 True 20 True
# 0 True 21 True
# 0 True 22 True
# 0 True 23 True
# 1 True 0 False
# 1 True 1 False
# 1 True 2 False
# 1 True 3 False
# 1 True 4 False
# 1 True 5 False
# 1 True 6 False
# 1 True 7 False
# 1 True 8 False
# 1 True 9 False
# 1 True 10 False
# 1 True 11 False
# 1 True 12 False
# 1 True 13 True
# 1 True 14 False
# 1 True 15 False
# 1 True 16 False
# 1 True 17 False
# 1 True 18 False
# 1 True 19 True
# 1 True 20 True
# 1 True 21 True
# 1 True 22 True
# 1 True 23 True
# 2 True 0 False
# 2 True 1 False
# 2 True 2 False
# ...

# %%
isPlayingDuringWorkingHours = []

for i in hourly_df.index:
    if i.dayofweek in range(5):
        if not ((i.hour > 12 and i.hour < 14) or i.hour > 18):
            isPlayingDuringWorkingHours.append(1)
        else:
            isPlayingDuringWorkingHours.append(0)
    else:
        isPlayingDuringWorkingHours.append(0)

hourly_df['isPlayingDuringWorkHours'] = isPlayingDuringWorkingHours
hourly_df
# Out:
#                            date  real_date  isPlayingDuringWorkHours
# real_date
# 2020-05-03 18:00:00+00:00     3          3                         0
# 2020-05-03 19:00:00+00:00     1          1                         0
# 2020-05-03 20:00:00+00:00     2          2                         0
# 2020-05-03 21:00:00+00:00     3          3                         0
# 2020-05-03 22:00:00+00:00     0          0                         0
# ...                         ...        ...                       ...
# 2020-05-12 15:00:00+00:00     0          0                         1
# 2020-05-12 16:00:00+00:00     0          0                         1
# 2020-05-12 17:00:00+00:00     0          0                         1
# 2020-05-12 18:00:00+00:00     3          3                         1
# 2020-05-12 19:00:00+00:00     2          2                         0
#
# [218 rows x 3 columns]

# %%
hourly_df['isPlayingDuringWorkHours'].sum()/len(hourly_df)
# Out:
# 0.5779816513761468

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (16,9))
plt.plot(hourly_df.index, hourly_df['date'])
