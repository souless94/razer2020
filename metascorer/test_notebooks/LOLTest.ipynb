# %%
import requests
import time
import datetime

# %%
lol_key = 'RGAPI-f0ac9728-40fe-4eeb-a1e3-3df02a6e7fd4'

headers = {"apiKey": lol_key,
           "region": "na1"}

# %%
account_id = 1584269368481

# %%
matches = requests.get("https://na1.api.riotgames.com/lol/match/v4/matchlists/by-account/XofAEbbZ2in_MtKIeX-mvDj1HjG4QG8US6t7jF_PqtXBxWg?api_key=RGAPI-7046925d-57cf-4d1a-ad54-7d7886243358")

# %%
matches.json()
# Out:
# {'matches': [{'platformId': 'NA1',
#    'gameId': 3325447955,
#    'champion': 24,
#    'queue': 450,
#    'season': 13,
#    'timestamp': 1584269368481,
#    'role': 'DUO_SUPPORT',
#    'lane': 'NONE'},
#   {'platformId': 'NA1',
#    'gameId': 3325449909,
#    'champion': 89,
#    'queue': 450,
#    'season': 13,
#    'timestamp': 1584267936055,
#    'role': 'DUO_SUPPORT',
#    'lane': 'MID'},
#   {'platformId': 'NA1',
#    'gameId': 3325428136,
#    'champion': 51,
#    'queue': 450,
#    'season': 13,
#    'timestamp': 1584266734425,
#    'role': 'DUO_SUPPORT',
#    'lane': 'NONE'},
#   {'platformId': 'NA1',
#    'gameId': 3325417416,
#    'champion': 45,
#    'queue': 450,
#    'season': 13,
#    'timestamp': 1584265510282,
#    'role': 'DUO_SUPPORT',
#    'lane': 'NONE'},
#   {'platformId': 'NA1',
#    'gameId': 3236987041,
#    'champion': 67,
#    'queue': 400,
#    'season': 13,
#    'timestamp': 1576494465938,
#    'role': 'DUO_CARRY',
#    'lane': 'BOTTOM'},
# ...

# %%
matches_list = matches.json()['matches']

# %%
len(matches_list)
# Out:
# 34

# %%
for match in matches_list:
    print(datetime.datetime.fromtimestamp(match['timestamp']/1000))
# Out:
# 2020-03-15 18:49:28.481000
# 2020-03-15 18:25:36.055000
# 2020-03-15 18:05:34.425000
# 2020-03-15 17:45:10.282000
# 2019-12-16 19:07:45.938000
# 2019-12-14 21:25:12.936000
# 2019-12-14 20:45:39.377000
# 2019-12-14 12:44:23.241000
# 2019-12-14 12:04:28.892000
# 2019-12-14 11:27:39.271000
# 2019-12-14 10:57:57.222000
# 2019-12-09 16:44:14.336000
# 2019-07-14 17:11:47.534000
# 2019-07-14 16:44:45.766000
# 2019-07-14 16:12:17.907000
# 2019-07-14 15:38:42.307000
# 2019-07-14 15:15:30.012000
# 2019-06-10 16:01:12.965000
# 2019-06-10 15:32:35.437000
# 2019-06-10 14:54:19.066000
# 2019-06-10 14:07:09.141000
# 2019-06-10 13:21:05.419000
# 2019-06-10 12:47:40.320000
# 2018-09-23 12:12:10.717000
# 2018-09-23 11:31:47.520000
# 2018-09-16 15:45:26.847000
# 2018-09-16 15:21:35.312000
# 2018-09-16 14:46:31.278000
# 2018-09-16 14:04:31.233000
# 2018-09-16 13:04:43.205000
# 2018-09-16 12:24:48.793000
# 2018-09-16 11:45:49.033000
# 2018-09-14 22:29:55.320000
# 2018-09-14 22:04:35.018000
